# %%
#| hide
from ros2_vision_system.core import *

# %% [markdown]
# # ros2_vision_system
#
# > Integration of a vision system with ros2 nodes

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install ros2_vision_system in Development mode

# %% [markdown]
# ```sh
# # make sure ros2_vision_system package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to ros2_vision_system
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/Ramon-PR/ros2_vision_system.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c Ramon-PR ros2_vision_system
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install ros2_vision_system
# ```
#
#
# [repo]: https://github.com/Ramon-PR/ros2_vision_system
# [docs]: https://Ramon-PR.github.io/ros2_vision_system/
# [pypi]: https://pypi.org/project/ros2_vision_system/
# [conda]: https://anaconda.org/Ramon-PR/ros2_vision_system

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/Ramon-PR/ros2_vision_system
# [docs]: https://Ramon-PR.github.io/ros2_vision_system/
# [pypi]: https://pypi.org/project/ros2_vision_system/
# [conda]: https://anaconda.org/Ramon-PR/ros2_vision_system

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
